# %% [markdown]
# En este notebook realizaremos tareas adicionales curso. Que forman parte de los desafios de cada modulo.

# %% [markdown]
# Desafio: lendo dados com vários parâmetros
#  Próxima Atividade
#
# Chegou a hora de você testar os conhecimentos desenvolvidos durante a aula. Temos um arquivo no formato CSV, que foi obtido na página Informações de Saúde (TABNET) - DATASUS. Este arquivo contém os gastos hospitalares públicos de cada uma das Unidades da Federação brasileira no período de janeiro de 2008 a março de 2021.
# ![]:'https://raw.githubusercontent.com/alura-cursos/Pandas/main/dados_sus.csv'
#
# Seu desafio aqui será fazer a leitura desse arquivo utilizando a função read_csv da biblioteca Pandas. Alguns parâmetros devem ser adicionados para que a leitura seja feita corretamente. Então, seguem algumas dicas:
#
# 1. Verifique se o arquivo CSV está separado por vírgula ou ponto e vírgula.
# 2. A codificação do arquivo é ISO-8859-1.
# 3. As três primeiras linhas linhas do arquivo podem ser desconsideradas, pois o cabeçalho só começa na quarta linha.
# 4. As 9 últimas linhas também podem ser desconsideradas, pois são apenas informações sobre onde os dados foram obtidos.
# 5. Para deletar as últimas linhas é necessário adicionar o parâmetro engine='python'.
# Vamos lá?

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/dados_sus.csv'

# %%
import pandas as pd

# %%
#Descomente para visualizar el resultado
#datos = pd.read_csv(url)

# %%
#Despues de visualizar el archivo vi que tiene un encabezado de texto y un pie de pagina también. 
#los datos estruturados estan desde la linea 4 hasta la linea 32
#Esta en portugués de brasil, por eso es "latin-1"
#Tipo de separacion generico para pt es ";"
datos = pd.read_csv(url, skiprows= 3, nrows= 29, header=None, encoding='latin-1', sep=';')
datos.head()
# Out:
#                     0           1           2           3           4    \
# 0  Unidade da Federação    2008/Jan    2008/Fev    2008/Mar    2008/Abr
# 1              Rondônia  1388528,39  2931283,42  1541682,52  1525314,96
# 2                  Acre   902416,00  1497206,26  1794028,48  1730469,42
# 3              Amazonas  4735529,42  7118990,57  8196635,49  8259378,42
# 4               Roraima   657889,53   777939,31   718688,03   839994,39
#
#           5           6           7           8           9    ...  \
# 0    2008/Mai    2008/Jun    2008/Jul    2008/Ago    2008/Set  ...
# 1  1645953,84  1406150,68  3065279,01  3231494,61  3117178,63  ...
# 2  1819443,92  1828496,00  2511754,59  2089107,14  2275708,53  ...
# 3  7831399,90  8477273,62  9368858,72  9352532,70  9363099,35  ...
# 4   862347,96   832440,66   996693,09   894271,18   910424,17  ...
#
#            151          152          153          154          155  \
# 0     2020/Jul     2020/Ago     2020/Set     2020/Out     2020/Nov
# 1  11824687,13  11733307,76  10201985,14   7955139,45   9357946,29
# 2   3915193,20   3640142,82   3391242,21   4044321,44   3276590,10
# 3  19769460,14  18059931,43  17841015,63  16408315,10  19895617,91
# 4   3015488,30   2826486,18   2928043,91   3090313,73   3621031,05
#
#            156          157          158          159            160
# 0     2020/Dez     2021/Jan     2021/Fev     2021/Mar          Total
# 1   8880836,55   9266014,59   7730597,04  11023309,47   996411254,68
# 2   3696997,31   3715723,12   3538427,92   4077045,92   450048530,47
# 3  17765167,69  21430289,17  25917134,55  22032176,22  1917247936,05
# 4   3454460,94   3266928,47   3519773,73   3985530,08   328876965,09
#
# [5 rows x 161 columns]

# %%
datos = pd.read_csv(url, encoding='ISO-8859-1', skiprows=3, skipfooter=9, engine='python', header=0, sep=';')
datos.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0             Rondônia   1388528,39   2931283,42   1541682,52   1525314,96
# 1                 Acre    902416,00   1497206,26   1794028,48   1730469,42
# 2             Amazonas   4735529,42   7118990,57   8196635,49   8259378,42
# 3              Roraima    657889,53    777939,31    718688,03    839994,39
# 4                 Pará  18864744,11  19553758,20  21937342,70  20842829,69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953,84   1406150,68   3065279,01   3231494,61   3117178,63  ...
# 1   1819443,92   1828496,00   2511754,59   2089107,14   2275708,53  ...
# 2   7831399,90   8477273,62   9368858,72   9352532,70   9363099,35  ...
# 3    862347,96    832440,66    996693,09    894271,18    910424,17  ...
# 4  23249952,88  23240687,56  24002223,56  23341218,03  25172261,32  ...
#
#       2020/Jul     2020/Ago     2020/Set     2020/Out     2020/Nov  \
# 0  11824687,13  11733307,76  10201985,14   7955139,45   9357946,29
# 1   3915193,20   3640142,82   3391242,21   4044321,44   3276590,10
# 2  19769460,14  18059931,43  17841015,63  16408315,10  19895617,91
# 3   3015488,30   2826486,18   2928043,91   3090313,73   3621031,05
# 4  40804126,43  44385715,88  36820249,47  36965931,34  39004315,80
#
#       2020/Dez     2021/Jan     2021/Fev     2021/Mar          Total
# 0   8880836,55   9266014,59   7730597,04  11023309,47   996411254,68
# 1   3696997,31   3715723,12   3538427,92   4077045,92   450048530,47
# 2  17765167,69  21430289,17  25917134,55  22032176,22  1917247936,05
# 3   3454460,94   3266928,47   3519773,73   3985530,08   328876965,09
# 4  38015145,79  38354682,46  37688314,23  33276392,89  4705309002,29
#
# [5 rows x 161 columns]
