# %%
#Importando biblioteca
import pandas as pd

# %%
datos = pd.read_json('base.json')
datos.head()
# Out:
#    id_paciente  doenca_cardiaca   imc  fumante  alcool faixa_etaria  \
# 0            1             True  27.3    False    True        31-40
# 1            2            False  22.8    False   False        21-30
# 2            3             True  31.6     True    True        51-60
# 3            4            False  18.9    False   False        18-20
# 4            5             True  29.4     True   False        41-50
#
#   raca_etnia  saude_fisica  saude_mental
# 0      Parda             4             7
# 1     Branca             9             8
# 2      Negra             3             5
# 3    Amarela            10             9
# 4   Indígena             5             4

# %%
datos["dicultade_caminar"] = False

# %%
datos.head()
# Out:
#    id_paciente  doenca_cardiaca   imc  fumante  alcool faixa_etaria  \
# 0            1             True  27.3    False    True        31-40
# 1            2            False  22.8    False   False        21-30
# 2            3             True  31.6     True    True        51-60
# 3            4            False  18.9    False   False        18-20
# 4            5             True  29.4     True   False        41-50
#
#   raca_etnia  saude_fisica  saude_mental  dicultade_caminar
# 0      Parda             4             7              False
# 1     Branca             9             8              False
# 2      Negra             3             5              False
# 3    Amarela            10             9              False
# 4   Indígena             5             4              False

# %%
pacientes2 = pd.read_json('pacientes2.json')
pacientes2
# Out:
#    id_paciente                                     dados_pessoais  \
# 0            1   {'faixa_etaria': '31-40', 'raca_etnia': 'Parda'}
# 1            2  {'faixa_etaria': '21-30', 'raca_etnia': 'Branca'}
# 2            3   {'faixa_etaria': '51-60', 'raca_etnia': 'Negra'}
#
#                                              habitos  \
# 0  {'fumante': False, 'alcool': True, 'atividade_...
# 1  {'fumante': False, 'alcool': False, 'atividade...
# 2  {'fumante': True, 'alcool': True, 'atividade_f...
#
#                                      condicoes_saude  \
# 0  {'doenca_cardiaca': True, 'imc': 27.3, 'pressa...
# 1  {'doenca_cardiaca': False, 'imc': 22.8, 'press...
# 2  {'doenca_cardiaca': True, 'imc': 31.6, 'pressa...
#
#                                            avaliacao
# 0  {'saude_fisica': 4, 'saude_mental': 7, 'sono':...
# 1  {'saude_fisica': 9, 'saude_mental': 8, 'sono':...
# 2  {'saude_fisica': 3, 'saude_mental': 5, 'sono':...

# %%
pacientes2_normalizados = pd.json_normalize(pacientes2['dados_pessoais'])
pacientes2_normalizados
# Out:
#   faixa_etaria raca_etnia
# 0        31-40      Parda
# 1        21-30     Branca
# 2        51-60      Negra

# %%
# Caso de practica
# Importando bibliotecas
import requests
import json

# %%
url = 'https://jsonplaceholder.typicode.com/users'

# %%
datos = requests.get(url)

# %%
resultado = json.loads(datos.text)

# %%
pd.DataFrame(resultado)
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# ...

# %%
pd.json_normalize(resultado)
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                    phone        website     address.street address.suite  \
# ...
